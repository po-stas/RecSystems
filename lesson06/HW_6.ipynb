# %% [markdown]
# ### Двухуровневая модель

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# Для работы с матрицами
from scipy.sparse import csr_matrix

# Матричная факторизация
from implicit import als

# Модель второго уровня
from lightgbm import LGBMClassifier

import os, sys
module_path = os.path.abspath(os.path.join(os.pardir))
if module_path not in sys.path:
    sys.path.append(module_path)

# Написанные нами функции
from src.metrics import precision_at_k, recall_at_k
from src.utils import prefilter_items
from src.recommenders import MainRecommender
from src.metrics import v_precision_at_k, v_recall_at_k

# %%
data = pd.read_csv('data/retail_train.csv')
data.head(2)
# Out:
#    user_id    basket_id  day  item_id  quantity  sales_value  store_id  \
# 0     2375  26984851472    1  1004906         1         1.39       364
# 1     2375  26984851472    1  1033142         1         0.82       364
#
#    retail_disc  trans_time  week_no  coupon_disc  coupon_match_disc
# 0         -0.6        1631        1          0.0                0.0
# 1          0.0        1631        1          0.0                0.0

# %% [markdown]
# ### Разделение на трейн-вал для двух-уровневой модели
# (Пока пойдем по предложенным на вебинаре параметрам)

# %%
val_lvl_1_size_weeks = 6
val_lvl_2_size_weeks = 3

data_train_lvl_1 = data[data['week_no'] < data['week_no'].max() - (val_lvl_1_size_weeks + val_lvl_2_size_weeks)]
data_val_lvl_1 = data[(data['week_no'] >= data['week_no'].max() - (val_lvl_1_size_weeks + val_lvl_2_size_weeks)) &
                      (data['week_no'] < data['week_no'].max() - (val_lvl_2_size_weeks))]

data_train_lvl_2 = data_val_lvl_1.copy()  # Для наглядности. Далее мы добавим изменения, и они будут отличаться
data_val_lvl_2 = data[data['week_no'] >= data['week_no'].max() - val_lvl_2_size_weeks]

data_train_lvl_1.head(2)
# Out:
#    user_id    basket_id  day  item_id  quantity  sales_value  store_id  \
# 0     2375  26984851472    1  1004906         1         1.39       364
# 1     2375  26984851472    1  1033142         1         0.82       364
#
#    retail_disc  trans_time  week_no  coupon_disc  coupon_match_disc
# 0         -0.6        1631        1          0.0                0.0
# 1          0.0        1631        1          0.0                0.0

# %%
# Тестовые таргеты для получения метрик на первом уровне
result_lvl_1 = data_val_lvl_1.groupby('user_id')['item_id'].unique().reset_index()
result_lvl_1.columns=['user_id', 'actual']
result_lvl_1.head(2)
# Out:
#    user_id                                             actual
# 0        1  [853529, 865456, 867607, 872137, 874905, 87524...
# 1        2  [15830248, 838136, 839656, 861272, 866211, 870...

# %%
# Модель первого уровня. Там будет ALS (и популярити рекомендации - для случаев отсутствия юзера в трейне)
first_level_model = MainRecommender(data_train_lvl_1, 
                                       n_factors=100,
                                       top_5000=True,
                                       strip_not_popular=False,
                                       strip_outdated=False,
                                       weighting=False,  
                                       K1=100,
                                       B=0.5)
# Out:
# /Users/postas/Anaconda/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
# WARNING:root:Intel MKL BLAS detected. Its highly recommend to set the environment variable 'export MKL_NUM_THREADS=1' to disable its internal multithreading
# HBox(children=(FloatProgress(value=0.0, max=15.0), HTML(value='')))

# %%
# Собираем результаты первого уровня. Если юзера не было в трейне но он есть в тесте -
# Он получает N популярных товаров в качестве рекомендаций
# Если у юзера из ALS получается меньше 50 рекомендаций - их дополняют популярные
result_lvl_1['als'] = first_level_model.get_all_recommendations(result_lvl_1['user_id'], N=50)

# %%
result_lvl_1.head()
# Out:
#    user_id                                             actual  \
# 0        1  [853529, 865456, 867607, 872137, 874905, 87524...
# 1        2  [15830248, 838136, 839656, 861272, 866211, 870...
# 2        4  [883932, 970760, 1035676, 1055863, 1097610, 67...
# 3        6  [1024306, 1102949, 6548453, 835394, 940804, 96...
# 4        7  [836281, 843306, 845294, 914190, 920456, 93886...
#
#                                                  als
# 0  [1132771, 867188, 958046, 1098248, 10149640, 8...
# 1  [1003421, 1071939, 1020581, 968215, 909714, 87...
# 2  [929668, 908531, 1048462, 8090521, 865705, 990...
# 3  [871611, 1041796, 996070, 1033220, 911878, 866...
# 4  [836281, 909894, 995242, 5591154, 6534178, 897...

# %%
v_precision_at_k(result_lvl_1.als, result_lvl_1.actual, k=50).mean()
# Out:
# 0.14163416898792947

# %%
v_recall_at_k(result_lvl_1.als, result_lvl_1.actual, k=50).mean()
# Out:
# 0.13740893696798437

# %% [markdown]
# ### Готовим данные на второй уровень

# %%
df=pd.DataFrame({'user_id':result_lvl_1.user_id.values.repeat(len(result_lvl_1.als[0])),
                 'item_id':np.concatenate(result_lvl_1.als.values)})
targets_lvl_2 = data_train_lvl_2[['user_id', 'item_id']].copy()
targets_lvl_2['target'] = 1  # тут только покупки 

targets_lvl_2 = df.merge(targets_lvl_2, on=['user_id', 'item_id'], how='left')

targets_lvl_2['target'].fillna(0, inplace= True)

# %%
df.head(2)
# Out:
#    user_id  item_id
# 0        1  1132771
# 1        1   867188

# %%
data_train_lvl_2.head()
# Out:
#          user_id    basket_id  day  item_id  quantity  sales_value  store_id  \
# 2104867     2070  40618492260  594  1019940         1         1.00       311
# 2107468     2021  40618753059  594   840361         1         0.99       443
# 2107469     2021  40618753059  594   856060         1         1.77       443
# 2107470     2021  40618753059  594   869344         1         1.67       443
# 2107471     2021  40618753059  594   896862         2         5.00       443
#
#          retail_disc  trans_time  week_no  coupon_disc  coupon_match_disc
# 2104867        -0.29          40       86          0.0                0.0
# 2107468         0.00         101       86          0.0                0.0
# 2107469        -0.09         101       86          0.0                0.0
# 2107470        -0.22         101       86          0.0                0.0
# 2107471        -2.98         101       86          0.0                0.0

# %%
targets_lvl_2['target'].mean()
# Out:
# 0.21034244176610775

# %%
targets_lvl_2.head()
# Out:
#    user_id   item_id  target  manufacturer department     brand  \
# 0        1   1132771     0.0          3787       DELI  National
# 1        1    867188     0.0          1046    GROCERY  National
# 2        1    958046     1.0           827    GROCERY  National
# 3        1   1098248     1.0             2    PRODUCE  National
# 4        1  10149640     1.0          1011    GROCERY  National
#
#          commodity_desc    sub_commodity_desc curr_size_of_product       0_x  \
# 0               CHEESES  CHEESE: NATURAL BULK                       0.003314
# 1   FROZEN PIE/DESSERTS  FRZN WHIPPED TOPPING                 8 OZ  0.005018
# 2  FRUIT - SHELF STABLE             PINEAPPLE                20 OZ  0.000943
# 3                 PEARS        PEARS BARTLETT                       0.007953
# 4          BATH TISSUES         TOILET TISSUE                       0.004682
#
#    ...      90_y    91_y      92_y      93_y      94_y      95_y      96_y  \
# 0  ...  4.921842  3.1956 -0.312043  0.663701  5.147588 -4.404645 -5.020015
# 1  ...  4.921842  3.1956 -0.312043  0.663701  5.147588 -4.404645 -5.020015
# 2  ...  4.921842  3.1956 -0.312043  0.663701  5.147588 -4.404645 -5.020015
# 3  ...  4.921842  3.1956 -0.312043  0.663701  5.147588 -4.404645 -5.020015
# 4  ...  4.921842  3.1956 -0.312043  0.663701  5.147588 -4.404645 -5.020015
#
#        97_y      98_y      99_y
# 0 -1.007887 -4.002372  2.887721
# 1 -1.007887 -4.002372  2.887721
# 2 -1.007887 -4.002372  2.887721
# 3 -1.007887 -4.002372  2.887721
# 4 -1.007887 -4.002372  2.887721
#
# [5 rows x 209 columns]

# %%
# Добавляем туда фичи айтемов
item_features = pd.read_csv('data/product.csv')
item_features.columns = [col.lower() for col in item_features.columns]
item_features.rename(columns={'product_id': 'item_id'}, inplace=True)

targets_lvl_2 = targets_lvl_2.merge(item_features, on='item_id', how='left')
targets_lvl_2.head()
# Out:
#    user_id   item_id  target  manufacturer department     brand  \
# 0        1   1132771     0.0        3787.0       DELI  National
# 1        1    867188     0.0        1046.0    GROCERY  National
# 2        1    958046     1.0         827.0    GROCERY  National
# 3        1   1098248     1.0           2.0    PRODUCE  National
# 4        1  10149640     1.0        1011.0    GROCERY  National
#
#          commodity_desc    sub_commodity_desc curr_size_of_product
# 0               CHEESES  CHEESE: NATURAL BULK
# 1   FROZEN PIE/DESSERTS  FRZN WHIPPED TOPPING                 8 OZ
# 2  FRUIT - SHELF STABLE             PINEAPPLE                20 OZ
# 3                 PEARS        PEARS BARTLETT
# 4          BATH TISSUES         TOILET TISSUE

# %%
# Добавляем туда эмбеддинги айтемов из ALS
embs = pd.DataFrame(first_level_model.model.item_factors)
embs['item_id'] = embs.index
embs['item_id'] = embs['item_id'].apply(lambda x: first_level_model.id_to_itemid[x])

targets_lvl_2 = targets_lvl_2.merge(embs, on='item_id', how='left')
targets_lvl_2.head()
# Out:
#    user_id   item_id  target  manufacturer department     brand  \
# 0        1   1132771     0.0        3787.0       DELI  National
# 1        1    867188     0.0        1046.0    GROCERY  National
# 2        1    958046     1.0         827.0    GROCERY  National
# 3        1   1098248     1.0           2.0    PRODUCE  National
# 4        1  10149640     1.0        1011.0    GROCERY  National
#
#          commodity_desc    sub_commodity_desc curr_size_of_product         0  \
# 0               CHEESES  CHEESE: NATURAL BULK                       0.003314
# 1   FROZEN PIE/DESSERTS  FRZN WHIPPED TOPPING                 8 OZ  0.005018
# 2  FRUIT - SHELF STABLE             PINEAPPLE                20 OZ  0.000943
# 3                 PEARS        PEARS BARTLETT                       0.007953
# 4          BATH TISSUES         TOILET TISSUE                       0.004682
#
#    ...        90        91        92        93        94        95        96  \
# 0  ...  0.016595  0.009209 -0.002801  0.009618  0.009802 -0.008644  0.020062
# 1  ...  0.027209  0.001818  0.016416 -0.001440 -0.004537  0.013130 -0.019439
# 2  ...  0.011196  0.010146  0.004122 -0.001052  0.004223  0.003454 -0.002848
# 3  ...  0.005468  0.022737  0.016989  0.011878  0.012684  0.014125  0.007525
# 4  ... -0.001779  0.009789  0.005005  0.005598  0.009248 -0.000633 -0.007506
#
#          97        98        99
# 0  0.006508 -0.002510  0.001342
# 1  0.008619  0.014195  0.010904
# 2  0.012128  0.012867  0.006614
# 3  0.002706  0.008896  0.005842
# 4  0.008811  0.005830 -0.002205
#
# [5 rows x 109 columns]

# %%
# Далее - ембеддинги юзеров (это будут единственные фичи по юзерам - 
# поскольку hh_demographics - не полный и скорее всего вообще не имеет к нам отношения)

# %%
embs = pd.DataFrame(first_level_model.model.user_factors)
embs['user_id'] = embs.index
embs['user_id'] = embs['user_id'].apply(lambda x: first_level_model.id_to_userid[x])

targets_lvl_2 = targets_lvl_2.merge(embs, on='user_id', how='left')
targets_lvl_2.head()
# Out:
#    user_id   item_id  target  manufacturer department     brand  \
# 0        1   1132771     0.0        3787.0       DELI  National
# 1        1    867188     0.0        1046.0    GROCERY  National
# 2        1    958046     1.0         827.0    GROCERY  National
# 3        1   1098248     1.0           2.0    PRODUCE  National
# 4        1  10149640     1.0        1011.0    GROCERY  National
#
#          commodity_desc    sub_commodity_desc curr_size_of_product       0_x  \
# 0               CHEESES  CHEESE: NATURAL BULK                       0.003314
# 1   FROZEN PIE/DESSERTS  FRZN WHIPPED TOPPING                 8 OZ  0.005018
# 2  FRUIT - SHELF STABLE             PINEAPPLE                20 OZ  0.000943
# 3                 PEARS        PEARS BARTLETT                       0.007953
# 4          BATH TISSUES         TOILET TISSUE                       0.004682
#
#    ...      90_y    91_y      92_y      93_y      94_y      95_y      96_y  \
# 0  ...  4.921842  3.1956 -0.312043  0.663701  5.147588 -4.404645 -5.020015
# 1  ...  4.921842  3.1956 -0.312043  0.663701  5.147588 -4.404645 -5.020015
# 2  ...  4.921842  3.1956 -0.312043  0.663701  5.147588 -4.404645 -5.020015
# 3  ...  4.921842  3.1956 -0.312043  0.663701  5.147588 -4.404645 -5.020015
# 4  ...  4.921842  3.1956 -0.312043  0.663701  5.147588 -4.404645 -5.020015
#
#        97_y      98_y      99_y
# 0 -1.007887 -4.002372  2.887721
# 1 -1.007887 -4.002372  2.887721
# 2 -1.007887 -4.002372  2.887721
# 3 -1.007887 -4.002372  2.887721
# 4 -1.007887 -4.002372  2.887721
#
# [5 rows x 209 columns]

# %%
targets_lvl_2.shape
# Out:
# (117071, 209)

# %%
cat_feats = ('manufacturer',
 'department',
 'brand',
 'commodity_desc',
 'sub_commodity_desc',
 'curr_size_of_product')

# %%
# Manufacturer - странное поле - выглядит как float но по смыслу это должен быть некий id
targets_lvl_2['manufacturer'] = targets_lvl_2['manufacturer'].fillna(0).astype('int')

# %%
targets_lvl_2.head()
# Out:
#    user_id   item_id  target  manufacturer department     brand  \
# 0        1   1132771     0.0          3787       DELI  National
# 1        1    867188     0.0          1046    GROCERY  National
# 2        1    958046     1.0           827    GROCERY  National
# 3        1   1098248     1.0             2    PRODUCE  National
# 4        1  10149640     1.0          1011    GROCERY  National
#
#          commodity_desc    sub_commodity_desc curr_size_of_product       0_x  \
# 0               CHEESES  CHEESE: NATURAL BULK                       0.003314
# 1   FROZEN PIE/DESSERTS  FRZN WHIPPED TOPPING                 8 OZ  0.005018
# 2  FRUIT - SHELF STABLE             PINEAPPLE                20 OZ  0.000943
# 3                 PEARS        PEARS BARTLETT                       0.007953
# 4          BATH TISSUES         TOILET TISSUE                       0.004682
#
#    ...      90_y    91_y      92_y      93_y      94_y      95_y      96_y  \
# 0  ...  4.921842  3.1956 -0.312043  0.663701  5.147588 -4.404645 -5.020015
# 1  ...  4.921842  3.1956 -0.312043  0.663701  5.147588 -4.404645 -5.020015
# 2  ...  4.921842  3.1956 -0.312043  0.663701  5.147588 -4.404645 -5.020015
# 3  ...  4.921842  3.1956 -0.312043  0.663701  5.147588 -4.404645 -5.020015
# 4  ...  4.921842  3.1956 -0.312043  0.663701  5.147588 -4.404645 -5.020015
#
#        97_y      98_y      99_y
# 0 -1.007887 -4.002372  2.887721
# 1 -1.007887 -4.002372  2.887721
# 2 -1.007887 -4.002372  2.887721
# 3 -1.007887 -4.002372  2.887721
# 4 -1.007887 -4.002372  2.887721
#
# [5 rows x 209 columns]

# %%
# Надо было стрипнуть оттуда 999999 - теперь у него наны в фичах
targets_lvl_2 = targets_lvl_2.fillna(0)

# %%
targets_lvl_2.describe()
# Out:
#              user_id       item_id         target   manufacturer  \
# count  117071.000000  1.170710e+05  117071.000000  117071.000000
# mean     1247.454664  1.623079e+06       0.210342     659.373269
# std       719.097502  1.989799e+06       0.407554    1215.944111
# min         1.000000  8.189800e+05       0.000000       0.000000
# 25%       627.000000  9.033250e+05       0.000000      69.000000
# 50%      1252.000000  9.958760e+05       0.000000      69.000000
# 75%      1864.000000  1.082185e+06       0.000000     759.000000
# max      2500.000000  1.592766e+07       1.000000    6331.000000
#
#                  0_x            1_x            2_x            3_x  \
# count  117071.000000  117071.000000  117071.000000  117071.000000
# mean        0.005507       0.006637       0.003527       0.005513
# std         0.008771       0.008681       0.008887       0.008748
# min        -0.026302      -0.017190      -0.021956      -0.023752
# 25%         0.000548       0.000699      -0.001916      -0.001078
# 50%         0.006085       0.006231       0.003360       0.006641
# 75%         0.010797       0.011308       0.008290       0.011524
# max         0.037347       0.032420       0.035733       0.036285
#
#                  4_x            5_x  ...           90_y           91_y  \
# count  117071.000000  117071.000000  ...  117071.000000  117071.000000
# mean        0.003915       0.005446  ...      -0.194989      -0.953215
# std         0.008660       0.009077  ...       2.898770       2.677695
# min        -0.022287      -0.022104  ...     -12.309825     -16.090813
# 25%        -0.000604      -0.000763  ...      -2.160346      -2.387689
# 50%         0.003226       0.005367  ...      -0.633807      -1.003487
# 75%         0.008885       0.011837  ...       1.431793       0.305583
# max         0.031098       0.032994  ...      11.173027      12.790009
#
#                 92_y           93_y           94_y           95_y  \
# count  117071.000000  117071.000000  117071.000000  117071.000000
# mean       -3.832024      -0.655766       1.961513      -3.488868
# std         2.770562       2.650566       2.583545       2.587128
# min       -15.890063     -13.939020      -9.172160     -14.752202
# 25%        -5.504837      -2.059971       0.615827      -4.851421
# 50%        -3.584659      -1.031029       1.781677      -3.728982
# 75%        -2.028195       0.663066       3.249728      -2.170223
# max         7.232758      13.049061      15.003448       7.810928
#
#                 96_y           97_y           98_y           99_y
# count  117071.000000  117071.000000  117071.000000  117071.000000
# mean        1.480280      -0.681189      -2.680624       4.319109
# std         2.711413       2.459437       2.630559       2.503356
# min       -13.508883     -13.013363     -12.290492      -8.558477
# 25%         0.083159      -1.940815      -4.214220       3.111503
# 50%         1.499941      -0.767395      -2.692656       4.167582
# 75%         2.911618       0.549368      -1.310789       5.450657
# max        12.480314      10.189717       8.175714      21.221157
#
# [8 rows x 204 columns]

# %%
targets_lvl_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 117071 entries, 0 to 117070
# Columns: 209 entries, user_id to 99_y
# dtypes: float32(200), float64(1), int64(3), object(5)
# memory usage: 98.2+ MB

# %% [markdown]
# ### Обучаем вторую модель

# %%
from sklearn.model_selection import train_test_split

# %%
def get_report(y_train_true, y_train_pred, y_test_true, y_test_pred):
    print('TRAIN\n-----------------------------\n' + classification_report(y_train_true, y_train_pred))
    print('\nTEST\n-----------------------------\n' + classification_report(y_test_true, y_test_pred))

# %%
X = targets_lvl_2.drop('target', axis=1)
y = targets_lvl_2[['target']]

# %%
# Учить и смотреть метрики в процессе учебы будем на втором трейне
# Финальный тест побережем на финальную оценку
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, shuffle=True, random_state=0)

# %%
lgb = LGBMClassifier(objective='binary', max_depth=7, categorical_column=cat_feats, )
lgb.fit(X_train, y_train)
# Out:
# /Users/postas/Anaconda/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-99-52867471d178> in <module>
#       1 lgb = LGBMClassifier(objective='binary', max_depth=7, categorical_column=cat_feats, )
# ----> 2 lgb.fit(X_train, y_train)
#
# ~/Anaconda/anaconda3/lib/python3.8/site-packages/lightgbm/sklearn.py in fit(self, X, y, sample_weight, init_score, eval_set, eval_names, eval_sample_weight, eval_class_weight, eval_init_score, eval_metric, early_stopping_rounds, verbose, feature_name, categorical_feature, callbacks, init_model)
#     845                     valid_sets[i] = (valid_x, self._le.transform(valid_y))
#     846
# --> 847         super(LGBMClassifier, self).fit(X, _y, sample_weight=sample_weight,
#     848                                         init_score=init_score, eval_set=valid_sets,
#     849                                         eval_names=eval_names,
#
# ~/Anaconda/anaconda3/lib/python3.8/site-packages/lightgbm/sklearn.py in fit(self, X, y, sample_weight, init_score, group, eval_set, eval_names, eval_sample_weight, eval_class_weight, eval_init_score, eval_group, eval_metric, early_stopping_rounds, verbose, feature_name, categorical_feature, callbacks, init_model)
#     610             init_model = init_model.booster_
#     611
# --> 612         self._Booster = train(params, train_set,
#     613                               self.n_estimators, valid_sets=valid_sets, valid_names=eval_names,
#     614                               early_stopping_rounds=early_stopping_rounds,
#
# ~/Anaconda/anaconda3/lib/python3.8/site-packages/lightgbm/engine.py in train(params, train_set, num_boost_round, valid_sets, valid_names, fobj, feval, init_model, feature_name, categorical_feature, early_stopping_rounds, evals_result, verbose_eval, learning_rates, keep_training_booster, callbacks)
#     229     # construct booster
#     230     try:
# --> 231         booster = Booster(params=params, train_set=train_set)
#     232         if is_valid_contain_train:
#     233             booster.set_train_data_name(train_data_name)
#
# ~/Anaconda/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py in __init__(self, params, train_set, model_file, model_str, silent)
#    2051                     break
#    2052             # construct booster object
# -> 2053             train_set.construct()
#    2054             # copy the parameters from train_set
#    2055             params.update(train_set.get_params())
#
# ~/Anaconda/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py in construct(self)
#    1319             else:
#    1320                 # create train
# -> 1321                 self._lazy_init(self.data, label=self.label,
#    1322                                 weight=self.weight, group=self.group,
#    1323                                 init_score=self.init_score, predictor=self._predictor,
#
# ~/Anaconda/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py in _lazy_init(self, data, label, reference, weight, group, init_score, predictor, silent, feature_name, categorical_feature, params)
#    1060             self.pandas_categorical = reference.pandas_categorical
#    1061             categorical_feature = reference.categorical_feature
# -> 1062         data, feature_name, categorical_feature, self.pandas_categorical = _data_from_pandas(data,
#    1063                                                                                              feature_name,
#    1064                                                                                              categorical_feature,
#
# ~/Anaconda/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py in _data_from_pandas(data, feature_name, categorical_feature, pandas_categorical)
#     393         bad_indices = _get_bad_pandas_dtypes(data.dtypes)
#     394         if bad_indices:
# --> 395             raise ValueError("DataFrame.dtypes for data must be int, float or bool.\n"
#     396                              "Did not expect the data types in the following fields: "
#     397                              + ', '.join(data.columns[bad_indices]))
#
# ValueError: DataFrame.dtypes for data must be int, float or bool.
# Did not expect the data types in the following fields: department, brand, commodity_desc, sub_commodity_desc, curr_size_of_product

# %%
# Эмм.. На вебинаре кажется говорилось, что lightgbm может нативно категориальные признаки... без one_hot..

# %%
# Окей - тогда catboost. Этот точно может
from catboost import CatBoostClassifier

# %%
model = CatBoostClassifier(
    iterations=50,
    learning_rate=0.1,
    loss_function='Logloss',
    custom_loss=['AUC', 'Accuracy']
)
model.fit(
    X_train, y_train,
    cat_features=cat_feats,
    eval_set=(X_test, y_test),
    plot=False,
    verbose=True
)
# Out:
# 0:	learn: 0.6508038	test: 0.6504680	best: 0.6504680 (0)	total: 105ms	remaining: 5.15s
# 1:	learn: 0.6145158	test: 0.6140570	best: 0.6140570 (1)	total: 200ms	remaining: 4.81s
# 2:	learn: 0.5872046	test: 0.5865507	best: 0.5865507 (2)	total: 286ms	remaining: 4.49s
# 3:	learn: 0.5637098	test: 0.5629327	best: 0.5629327 (3)	total: 409ms	remaining: 4.71s
# 4:	learn: 0.5441255	test: 0.5432595	best: 0.5432595 (4)	total: 488ms	remaining: 4.39s
# 5:	learn: 0.5290393	test: 0.5282379	best: 0.5282379 (5)	total: 564ms	remaining: 4.14s
# 6:	learn: 0.5163725	test: 0.5155875	best: 0.5155875 (6)	total: 640ms	remaining: 3.93s
# 7:	learn: 0.5059244	test: 0.5050873	best: 0.5050873 (7)	total: 745ms	remaining: 3.91s
# 8:	learn: 0.4975402	test: 0.4967207	best: 0.4967207 (8)	total: 830ms	remaining: 3.78s
# 9:	learn: 0.4878118	test: 0.4871720	best: 0.4871720 (9)	total: 931ms	remaining: 3.73s
# 10:	learn: 0.4803667	test: 0.4798919	best: 0.4798919 (10)	total: 1.01s	remaining: 3.57s
# 11:	learn: 0.4736366	test: 0.4730705	best: 0.4730705 (11)	total: 1.07s	remaining: 3.4s
# 12:	learn: 0.4685349	test: 0.4680229	best: 0.4680229 (12)	total: 1.17s	remaining: 3.34s
# 13:	learn: 0.4637992	test: 0.4632502	best: 0.4632502 (13)	total: 1.25s	remaining: 3.22s
# 14:	learn: 0.4599820	test: 0.4595781	best: 0.4595781 (14)	total: 1.32s	remaining: 3.09s
# 15:	learn: 0.4566342	test: 0.4562185	best: 0.4562185 (15)	total: 1.4s	remaining: 2.98s
# 16:	learn: 0.4537442	test: 0.4534140	best: 0.4534140 (16)	total: 1.5s	remaining: 2.92s
# 17:	learn: 0.4505970	test: 0.4503049	best: 0.4503049 (17)	total: 1.6s	remaining: 2.84s
# 18:	learn: 0.4484093	test: 0.4482801	best: 0.4482801 (18)	total: 2.33s	remaining: 3.8s
# 19:	learn: 0.4461171	test: 0.4462170	best: 0.4462170 (19)	total: 2.67s	remaining: 4s
# 20:	learn: 0.4441025	test: 0.4443136	best: 0.4443136 (20)	total: 3.02s	remaining: 4.17s
# 21:	learn: 0.4419503	test: 0.4421590	best: 0.4421590 (21)	total: 3.57s	remaining: 4.54s
# 22:	learn: 0.4397525	test: 0.4399577	best: 0.4399577 (22)	total: 3.68s	remaining: 4.32s
# 23:	learn: 0.4379346	test: 0.4380470	best: 0.4380470 (23)	total: 3.75s	remaining: 4.06s
# 24:	learn: 0.4363245	test: 0.4364982	best: 0.4364982 (24)	total: 3.87s	remaining: 3.87s
# 25:	learn: 0.4347008	test: 0.4349628	best: 0.4349628 (25)	total: 3.94s	remaining: 3.63s
# 26:	learn: 0.4334690	test: 0.4337890	best: 0.4337890 (26)	total: 4s	remaining: 3.41s
# 27:	learn: 0.4320497	test: 0.4325725	best: 0.4325725 (27)	total: 4.07s	remaining: 3.2s
# 28:	learn: 0.4308108	test: 0.4313192	best: 0.4313192 (28)	total: 4.19s	remaining: 3.03s
# 29:	learn: 0.4300086	test: 0.4306054	best: 0.4306054 (29)	total: 4.25s	remaining: 2.83s
# 30:	learn: 0.4291433	test: 0.4297134	best: 0.4297134 (30)	total: 4.33s	remaining: 2.65s
# 31:	learn: 0.4282626	test: 0.4289258	best: 0.4289258 (31)	total: 4.42s	remaining: 2.48s
# 32:	learn: 0.4272850	test: 0.4280061	best: 0.4280061 (32)	total: 4.49s	remaining: 2.31s
# 33:	learn: 0.4263248	test: 0.4272414	best: 0.4272414 (33)	total: 4.56s	remaining: 2.15s
# 34:	learn: 0.4253083	test: 0.4263116	best: 0.4263116 (34)	total: 4.65s	remaining: 1.99s
# 35:	learn: 0.4244065	test: 0.4253922	best: 0.4253922 (35)	total: 4.73s	remaining: 1.84s
# 36:	learn: 0.4237004	test: 0.4248251	best: 0.4248251 (36)	total: 4.82s	remaining: 1.69s
# 37:	learn: 0.4226628	test: 0.4238118	best: 0.4238118 (37)	total: 4.91s	remaining: 1.55s
# 38:	learn: 0.4217742	test: 0.4229256	best: 0.4229256 (38)	total: 4.98s	remaining: 1.4s
# 39:	learn: 0.4211598	test: 0.4224195	best: 0.4224195 (39)	total: 5.04s	remaining: 1.26s
# 40:	learn: 0.4204827	test: 0.4217551	best: 0.4217551 (40)	total: 5.15s	remaining: 1.13s
# 41:	learn: 0.4199439	test: 0.4212407	best: 0.4212407 (41)	total: 5.25s	remaining: 1s
# 42:	learn: 0.4192689	test: 0.4206254	best: 0.4206254 (42)	total: 5.33s	remaining: 867ms
# 43:	learn: 0.4184855	test: 0.4200001	best: 0.4200001 (43)	total: 5.42s	remaining: 740ms
# 44:	learn: 0.4179249	test: 0.4195917	best: 0.4195917 (44)	total: 5.49s	remaining: 611ms
# 45:	learn: 0.4174681	test: 0.4191830	best: 0.4191830 (45)	total: 5.56s	remaining: 484ms
# 46:	learn: 0.4170230	test: 0.4187754	best: 0.4187754 (46)	total: 5.63s	remaining: 359ms
# 47:	learn: 0.4163989	test: 0.4182177	best: 0.4182177 (47)	total: 5.73s	remaining: 239ms
# 48:	learn: 0.4158091	test: 0.4177412	best: 0.4177412 (48)	total: 5.81s	remaining: 118ms
# 49:	learn: 0.4154615	test: 0.4174975	best: 0.4174975 (49)	total: 6.32s	remaining: 0us
#
# bestTest = 0.4174974963
# bestIteration = 49

# %%
# Как-то учится. Можно даже продолжать наверное еще.
# А еще красивые catboost графики рисует.. с plot=True, по test-ROC-AUC на них получается 0.79.. test-accuracy 0.816
# Ну - это ведь далеко не конечный результат еще. Надо теперь прогнать на test-е и взять 5 с наибольшей вероятностью
# тогда уже можно будет посмотреть скор

# %%
data_val_lvl_2.head(2)
# Out:
#          user_id    basket_id  day  item_id  quantity  sales_value  store_id  \
# 2277416      338  41260573635  636   840173         1         1.99       369
# 2277417      338  41260573635  636  1037348         1         0.89       369
#
#          retail_disc  trans_time  week_no  coupon_disc  coupon_match_disc
# 2277416          0.0         112       92          0.0                0.0
# 2277417         -0.3         112       92          0.0                0.0

# %%
# Делаем таргеты для теста второго уровня (метрики считать) 
# и получаем рекомендации от фильтрующей модели
result_lvl_2 = data_val_lvl_2.groupby('user_id')['item_id'].unique().reset_index()
result_lvl_2.columns = ('user_id', 'actual')
result_lvl_2['als'] = first_level_model.get_all_recommendations(result_lvl_2['user_id'], N=50)
result_lvl_2.head(2)
# Out:
#    user_id                                             actual  \
# 0        1  [821867, 834484, 856942, 865456, 889248, 90795...
# 1        3  [835476, 851057, 872021, 878302, 879948, 90963...
#
#                                                  als
# 0  [1132771, 867188, 958046, 1098248, 10149640, 8...
# 1  [844179, 859075, 12810393, 940947, 6463658, 10...

# %%
# Делаем пары user_id - item_id
df=pd.DataFrame({'user_id':result_lvl_2.user_id.values.repeat(len(result_lvl_2.als[0])),
                 'item_id':np.concatenate(result_lvl_2.als.values)})

df.head()
# Out:
#    user_id   item_id
# 0        1   1132771
# 1        1    867188
# 2        1    958046
# 3        1   1098248
# 4        1  10149640

# %%
# Теперь сюда надо опять добавить айтем-фичи + айтем-ембеддинги + юзер-ембеддниги
val_lvl_2 = df.copy()

# %%
# Добавляем туда фичи айтемов
val_lvl_2 = val_lvl_2.merge(item_features, on='item_id', how='left')
val_lvl_2.head(2)
# Out:
#    user_id  item_id  manufacturer department     brand       commodity_desc  \
# 0        1  1132771        3787.0       DELI  National              CHEESES
# 1        1   867188        1046.0    GROCERY  National  FROZEN PIE/DESSERTS
#
#      sub_commodity_desc curr_size_of_product
# 0  CHEESE: NATURAL BULK
# 1  FRZN WHIPPED TOPPING                 8 OZ

# %%
# Эмбеддинги айтемов из ALS
embs = pd.DataFrame(first_level_model.model.item_factors)
embs['item_id'] = embs.index
embs['item_id'] = embs['item_id'].apply(lambda x: first_level_model.id_to_itemid[x])

val_lvl_2 = val_lvl_2.merge(embs, on='item_id', how='left')
val_lvl_2.head(2)
# Out:
#    user_id  item_id  manufacturer department     brand       commodity_desc  \
# 0        1  1132771        3787.0       DELI  National              CHEESES
# 1        1   867188        1046.0    GROCERY  National  FROZEN PIE/DESSERTS
#
#      sub_commodity_desc curr_size_of_product         0         1  ...  \
# 0  CHEESE: NATURAL BULK                       0.003314 -0.003628  ...
# 1  FRZN WHIPPED TOPPING                 8 OZ  0.005018 -0.004096  ...
#
#          90        91        92        93        94        95        96  \
# 0  0.016595  0.009209 -0.002801  0.009618  0.009802 -0.008644  0.020062
# 1  0.027209  0.001818  0.016416 -0.001440 -0.004537  0.013130 -0.019439
#
#          97        98        99
# 0  0.006508 -0.002510  0.001342
# 1  0.008619  0.014195  0.010904
#
# [2 rows x 108 columns]

# %%
# Юзер эмбеддинги
embs = pd.DataFrame(first_level_model.model.user_factors)
embs['user_id'] = embs.index
embs['user_id'] = embs['user_id'].apply(lambda x: first_level_model.id_to_userid[x])

val_lvl_2 = val_lvl_2.merge(embs, on='user_id', how='left')
val_lvl_2.head()
# Out:
#    user_id   item_id  manufacturer department     brand        commodity_desc  \
# 0        1   1132771        3787.0       DELI  National               CHEESES
# 1        1    867188        1046.0    GROCERY  National   FROZEN PIE/DESSERTS
# 2        1    958046         827.0    GROCERY  National  FRUIT - SHELF STABLE
# 3        1   1098248           2.0    PRODUCE  National                 PEARS
# 4        1  10149640        1011.0    GROCERY  National          BATH TISSUES
#
#      sub_commodity_desc curr_size_of_product       0_x       1_x  ...  \
# 0  CHEESE: NATURAL BULK                       0.003314 -0.003628  ...
# 1  FRZN WHIPPED TOPPING                 8 OZ  0.005018 -0.004096  ...
# 2             PINEAPPLE                20 OZ  0.000943  0.000465  ...
# 3        PEARS BARTLETT                       0.007953  0.003463  ...
# 4         TOILET TISSUE                       0.004682  0.004622  ...
#
#        90_y    91_y      92_y      93_y      94_y      95_y      96_y  \
# 0  4.921842  3.1956 -0.312043  0.663701  5.147588 -4.404645 -5.020015
# 1  4.921842  3.1956 -0.312043  0.663701  5.147588 -4.404645 -5.020015
# 2  4.921842  3.1956 -0.312043  0.663701  5.147588 -4.404645 -5.020015
# 3  4.921842  3.1956 -0.312043  0.663701  5.147588 -4.404645 -5.020015
# 4  4.921842  3.1956 -0.312043  0.663701  5.147588 -4.404645 -5.020015
#
#        97_y      98_y      99_y
# 0 -1.007887 -4.002372  2.887721
# 1 -1.007887 -4.002372  2.887721
# 2 -1.007887 -4.002372  2.887721
# 3 -1.007887 -4.002372  2.887721
# 4 -1.007887 -4.002372  2.887721
#
# [5 rows x 208 columns]

# %%
# И опять manufacturer в int (надо класс для модели второго уровня делать тоже - чтобы не повторять это все заново)
# Ну или в пайплайн заворачивать
val_lvl_2['manufacturer'] = val_lvl_2['manufacturer'].fillna(0).astype('int')

# %%
val_lvl_2 = val_lvl_2.fillna(0)
val_lvl_2.head()
# Out:
#    user_id   item_id  manufacturer department     brand        commodity_desc  \
# 0        1   1132771          3787       DELI  National               CHEESES
# 1        1    867188          1046    GROCERY  National   FROZEN PIE/DESSERTS
# 2        1    958046           827    GROCERY  National  FRUIT - SHELF STABLE
# 3        1   1098248             2    PRODUCE  National                 PEARS
# 4        1  10149640          1011    GROCERY  National          BATH TISSUES
#
#      sub_commodity_desc curr_size_of_product       0_x       1_x  ...  \
# 0  CHEESE: NATURAL BULK                       0.003314 -0.003628  ...
# 1  FRZN WHIPPED TOPPING                 8 OZ  0.005018 -0.004096  ...
# 2             PINEAPPLE                20 OZ  0.000943  0.000465  ...
# 3        PEARS BARTLETT                       0.007953  0.003463  ...
# 4         TOILET TISSUE                       0.004682  0.004622  ...
#
#        90_y    91_y      92_y      93_y      94_y      95_y      96_y  \
# 0  4.921842  3.1956 -0.312043  0.663701  5.147588 -4.404645 -5.020015
# 1  4.921842  3.1956 -0.312043  0.663701  5.147588 -4.404645 -5.020015
# 2  4.921842  3.1956 -0.312043  0.663701  5.147588 -4.404645 -5.020015
# 3  4.921842  3.1956 -0.312043  0.663701  5.147588 -4.404645 -5.020015
# 4  4.921842  3.1956 -0.312043  0.663701  5.147588 -4.404645 -5.020015
#
#        97_y      98_y      99_y
# 0 -1.007887 -4.002372  2.887721
# 1 -1.007887 -4.002372  2.887721
# 2 -1.007887 -4.002372  2.887721
# 3 -1.007887 -4.002372  2.887721
# 4 -1.007887 -4.002372  2.887721
#
# [5 rows x 208 columns]

# %%
val_lvl_2.shape
# Out:
# (102100, 208)

# %% [markdown]
# ### Данные последнего теста готовы - запускаем классифайер

# %%
preds = model.predict_proba(val_lvl_2)

# %%
# Мерджим вероятности с юзерами-айтемами (для последующей сортировки)
preds_df = pd.DataFrame(preds[:,1:])
preds_df.columns = ('probabilities',)
prob_df = df.join(preds_df)
prob_df.head()
# Out:
#    user_id   item_id  probabilities
# 0        1   1132771       0.304914
# 1        1    867188       0.280074
# 2        1    958046       0.470006
# 3        1   1098248       0.298016
# 4        1  10149640       0.230087

# %%
# Теперь надо айтемы сгруппировать по юзеру сортируя по убыванию probability

# %%
sorted_prob = prob_df.sort_values('probabilities', ascending=False).reset_index(drop=True)
test_result = sorted_prob.groupby('user_id')['item_id'].unique().reset_index()
test_result.head()
# Out:
#    user_id                                            item_id
# 0        1  [1082185, 1029743, 995242, 958046, 940947, 100...
# 1        3  [1082185, 1106523, 1133018, 940947, 1110244, 1...
# 2        6  [1082185, 1029743, 995242, 1070820, 862349, 98...
# 3        7  [1082185, 1106523, 6534178, 1126899, 995242, 5...
# 4        8  [1082185, 1106523, 1029743, 6534178, 1133018, ...

# %%
# Пришла пора посмотреть - насколько правильно получилось все это сделать...

# %%
v_precision_at_k(test_result.item_id, result_lvl_2.actual).mean()
# Out:
# 0.2514201762977474

# %%
# Фух... так. Ожидалось конечно сразу 0.9 :)) но судя по цифре скора - видимо все работает правильно.
# Если бы я где-то совсем накосячил - было бы что-то типа 0.05 (такой вариант тоже ожидался :)
# А 0.251 - больше чем получалось на own и на ALS и на чем бы то ни было до этого.
# Но - поработать все-же придется )
# Будем считать это бэйзлайном и прув оф концепт для двухуровневой модели 
# И займемся фильтрацией исходных интеракций, фиче-инжинирингом и тюнингом бустинга в конце-концов..
